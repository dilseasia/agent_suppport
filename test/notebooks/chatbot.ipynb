# %%
tools = [
        {
            "type": "function",
            "function": {
                "name": "get_weather",
                "description": "Get current weather for a city",
                "parameters": {
                    "type": "object",
                    "properties": {
                        "city": {"type": "string"}
                    },
                    "required": ["city"]
                }
            }
        },
        {
            "type": "function",
            "function": {
                "name": "get_dealership_address",
                "description": "Retrieve dealership address and details",
                "parameters": {
                    "type": "object",
                    "properties": {
                        "dealership_id": {"type": "string"}
                    },
                    "required": ["dealership_id"]
                }
            }
        },
        {
            "type": "function",
            "function": {
                "name": "check_appointment_availability",
                "description": "Check available appointment slots for a dealership on a specific date",
                "parameters": {
                    "type": "object",
                    "properties": {
                        "dealership_id": {"type": "string"},
                        "date": {"type": "string"}
                    },
                    "required": ["dealership_id", "date"]
                }
            }
        },
        {
            "type": "function",
            "function": {
                "name": "schedule_appointment",
                "description": "Schedule an appointment at a SuperCar dealership",
                "parameters": {
                    "type": "object",
                    "properties": {
                        "user_id": {"type": "string"},
                        "dealership_id": {"type": "string"},
                        "date": {"type": "string"},
                        "time": {"type": "string"},
                        "car_model": {"type": "string"}
                    },
                    "required": ["user_id", "dealership_id", "date", "time", "car_model"]
                }
            }
        }
    ]

# %%
{
            "vehicle_inventory": {
                "description": "Detailed vehicle inventory management",
                "categories": [
                    "Electric Vehicles",
                    "Luxury Sedans", 
                    "SUVs", 
                    "Sports Cars"
                ],
                "data_sources": {
                    "mongodb": "vehicle_inventory",
                    "redis_cache": "vehicle_inventory_cache"
                }
            },
            "appointment_scheduling": {
                "description": "Advanced appointment booking system",
                "service_types": [
                    "Sales Consultation",
                    "Test Drive",
                    "Service Maintenance",
                    "Customization Consultation"
                ],
                "booking_channels": [
                    "Online", 
                    "Phone", 
                    "In-Person", 
                    "Mobile App"
                ]
            },
            "weather_integration": {
                "description": "Location-based weather analysis for service planning",
                "data_points": [
                    "Temperature",
                    "Precipitation",
                    "Wind Speed",
                    "Humidity"
                ],
                "impact_areas": [
                    "Test Drive Scheduling",
                    "Maintenance Recommendations",
                    "Service Center Preparedness"
                ]
            },
            "customer_support": {
                "description": "Multi-channel customer support system",
                "support_channels": [
                    "Live Chat",
                    "Email",
                    "Phone",
                    "Social Media",
                    "In-Person"
                ],
                "response_categories": [
                    "Sales Inquiry",
                    "Technical Support",
                    "Service Scheduling",
                    "Complaint Resolution"
                ]
            }
        }

# %%
{
    "dealerships": [
        {
            "id": "NYC_MANHATTAN_01",
            "name": "SuperCar Manhattan Flagship",
            "location": {
                "address": "123 Broadway, New York, NY 10001",
                "coordinates": {
                    "latitude": 40.7128,
                    "longitude": -74.0060
                },
                "timezone": "America/New_York"
            },
            "contact": {
                "phone": "+1 (212) 555-1234",
                "email": "manhattan@supercar.com",
                "website": "https://supercar.com/manhattan"
            },
            "operating_hours": {
                "weekdays": {
                    "open": "09:00",
                    "close": "20:00"
                },
                "weekends": {
                    "open": "10:00",
                    "close": "18:00"
                },
                "holidays": "Closed on major holidays"
            },
            "services": {
                "sales": true,
                "service": true,
                "test_drives": true,
                "financing": true
            },
            "inventory_specialties": [
                "Luxury Sedans",
                "Electric Vehicles",
                "High-Performance Sports Cars"
            ],
            "amenities": [
                "Free Wi-Fi",
                "Complimentary Coffee",
                "Waiting Lounge",
                "Digital Vehicle Configurator"
            ],
            "staff_expertise": {
                "sales_consultants": 15,
                "service_technicians": 20,
                "avg_experience_years": 7.5
            },
            "customer_ratings": {
                "overall_rating": 4.7,
                "total_reviews": 1250,
                "rating_sources": [
                    "Google Reviews",
                    "Yelp",
                    "DealerRater"
                ]
            }
        },
        {
            "id": "LA_SUNSET_01",
            "name": "SuperCar Los Angeles Showroom",
            "location": {
                "address": "456 Sunset Boulevard, Los Angeles, CA 90028",
                "coordinates": {
                    "latitude": 34.0522,
                    "longitude": -118.2437
                },
                "timezone": "America/Los_Angeles"
            },
            "contact": {
                "phone": "+1 (323) 555-5678",
                "email": "losangeles@supercar.com",
                "website": "https://supercar.com/losangeles"
            },
            "operating_hours": {
                "weekdays": {
                    "open": "10:00",
                    "close": "21:00"
                },
                "weekends": {
                    "open": "09:00",
                    "close": "19:00"
                },
                "holidays": "Reduced hours on major holidays"
            },
            "services": {
                "sales": true,
                "service": true,
                "test_drives": true,
                "customization": true
            },
            "inventory_specialties": [
                "Electric SUVs",
                "Performance Coupes",
                "Luxury Convertibles"
            ],
            "amenities": [
                "Virtual Reality Showroom",
                "Complimentary Valet",
                "Private Consultation Rooms",
                "Tesla Charging Stations"
            ],
            "staff_expertise": {
                "sales_consultants": 22,
                "service_technicians": 30,
                "avg_experience_years": 9.2
            },
            "customer_ratings": {
                "overall_rating": 4.9,
                "total_reviews": 2100,
                "rating_sources": [
                    "Google Reviews",
                    "Yelp",
                    "DealerRater"
                ]
            }
        }
    ]
}

# %%
{
            "vehicle_inventory": {
                "description": "Detailed vehicle inventory management",
                "categories": [
                    "Electric Vehicles",
                    "Luxury Sedans", 
                    "SUVs", 
                    "Sports Cars"
                ],
                "data_sources": {
                    "mongodb": "vehicle_inventory",
                    "redis_cache": "vehicle_inventory_cache"
                }
            },
            "appointment_scheduling": {
                "description": "Advanced appointment booking system",
                "service_types": [
                    "Sales Consultation",
                    "Test Drive",
                    "Service Maintenance",
                    "Customization Consultation"
                ],
                "booking_channels": [
                    "Online", 
                    "Phone", 
                    "In-Person", 
                    "Mobile App"
                ]
            },
            "weather_integration": {
                "description": "Location-based weather analysis for service planning",
                "data_points": [
                    "Temperature",
                    "Precipitation",
                    "Wind Speed",
                    "Humidity"
                ],
                "impact_areas": [
                    "Test Drive Scheduling",
                    "Maintenance Recommendations",
                    "Service Center Preparedness"
                ]
            },
            "customer_support": {
                "description": "Multi-channel customer support system",
                "support_channels": [
                    "Live Chat",
                    "Email",
                    "Phone",
                    "Social Media",
                    "In-Person"
                ],
                "response_categories": [
                    "Sales Inquiry",
                    "Technical Support",
                    "Service Scheduling",
                    "Complaint Resolution"
                ]
            }
        }


tools = [
        {
            "type": "function",
            "function": {
                "name": "get_weather",
                "description": "Get current weather for a city",
                "parameters": {
                    "type": "object",
                    "properties": {
                        "city": {"type": "string"}
                    },
                    "required": ["city"]
                }
            }
        },
        {
            "type": "function",
            "function": {
                "name": "get_dealership_address",
                "description": "Retrieve dealership address and details",
                "parameters": {
                    "type": "object",
                    "properties": {
                        "dealership_id": {"type": "string"}
                    },
                    "required": ["dealership_id"]
                }
            }
        },
        {
            "type": "function",
            "function": {
                "name": "check_appointment_availability",
                "description": "Check available appointment slots for a dealership on a specific date",
                "parameters": {
                    "type": "object",
                    "properties": {
                        "dealership_id": {"type": "string"},
                        "date": {"type": "string"}
                    },
                    "required": ["dealership_id", "date"]
                }
            }
        },
        {
            "type": "function",
            "function": {
                "name": "schedule_appointment",
                "description": "Schedule an appointment at a SuperCar dealership",
                "parameters": {
                    "type": "object",
                    "properties": {
                        "user_id": {"type": "string"},
                        "dealership_id": {"type": "string"},
                        "date": {"type": "string"},
                        "time": {"type": "string"},
                        "car_model": {"type": "string"}
                    },
                    "required": ["user_id", "dealership_id", "date", "time", "car_model"]
                }
            }
        }
    ]




data = 
{
    "dealerships": [
        {
            "id": "NYC_MANHATTAN_01",
            "name": "SuperCar Manhattan Flagship",
            "location": {
                "address": "123 Broadway, New York, NY 10001",
                "coordinates": {
                    "latitude": 40.7128,
                    "longitude": -74.0060
                },
                "timezone": "America/New_York"
            },
            "contact": {
                "phone": "+1 (212) 555-1234",
                "email": "manhattan@supercar.com",
                "website": "https://supercar.com/manhattan"
            },
            "operating_hours": {
                "weekdays": {
                    "open": "09:00",
                    "close": "20:00"
                },
                "weekends": {
                    "open": "10:00",
                    "close": "18:00"
                },
                "holidays": "Closed on major holidays"
            },
            "services": {
                "sales": true,
                "service": true,
                "test_drives": true,
                "financing": true
            },
            "inventory_specialties": [
                "Luxury Sedans",
                "Electric Vehicles",
                "High-Performance Sports Cars"
            ],
            "amenities": [
                "Free Wi-Fi",
                "Complimentary Coffee",
                "Waiting Lounge",
                "Digital Vehicle Configurator"
            ],
            "staff_expertise": {
                "sales_consultants": 15,
                "service_technicians": 20,
                "avg_experience_years": 7.5
            },
            "customer_ratings": {
                "overall_rating": 4.7,
                "total_reviews": 1250,
                "rating_sources": [
                    "Google Reviews",
                    "Yelp",
                    "DealerRater"
                ]
            }
        },
        {
            "id": "LA_SUNSET_01",
            "name": "SuperCar Los Angeles Showroom",
            "location": {
                "address": "456 Sunset Boulevard, Los Angeles, CA 90028",
                "coordinates": {
                    "latitude": 34.0522,
                    "longitude": -118.2437
                },
                "timezone": "America/Los_Angeles"
            },
            "contact": {
                "phone": "+1 (323) 555-5678",
                "email": "losangeles@supercar.com",
                "website": "https://supercar.com/losangeles"
            },
            "operating_hours": {
                "weekdays": {
                    "open": "10:00",
                    "close": "21:00"
                },
                "weekends": {
                    "open": "09:00",
                    "close": "19:00"
                },
                "holidays": "Reduced hours on major holidays"
            },
            "services": {
                "sales": true,
                "service": true,
                "test_drives": true,
                "customization": true
            },
            "inventory_specialties": [
                "Electric SUVs",
                "Performance Coupes",
                "Luxury Convertibles"
            ],
            "amenities": [
                "Virtual Reality Showroom",
                "Complimentary Valet",
                "Private Consultation Rooms",
                "Tesla Charging Stations"
            ],
            "staff_expertise": {
                "sales_consultants": 22,
                "service_technicians": 30,
                "avg_experience_years": 9.2
            },
            "customer_ratings": {
                "overall_rating": 4.9,
                "total_reviews": 2100,
                "rating_sources": [
                    "Google Reviews",
                    "Yelp",
                    "DealerRater"
                ]
            }
        }
    ]
}
# Out:
# {'vehicle_inventory': {'description': 'Detailed vehicle inventory management',
#   'categories': ['Electric Vehicles', 'Luxury Sedans', 'SUVs', 'Sports Cars'],
#   'data_sources': {'mongodb': 'vehicle_inventory',
#    'redis_cache': 'vehicle_inventory_cache'}},
#  'appointment_scheduling': {'description': 'Advanced appointment booking system',
#   'service_types': ['Sales Consultation',
#    'Test Drive',
#    'Service Maintenance',
#    'Customization Consultation'],
#   'booking_channels': ['Online', 'Phone', 'In-Person', 'Mobile App']},
#  'weather_integration': {'description': 'Location-based weather analysis for service planning',
#   'data_points': ['Temperature', 'Precipitation', 'Wind Speed', 'Humidity'],
#   'impact_areas': ['Test Drive Scheduling',
#    'Maintenance Recommendations',
#    'Service Center Preparedness']},
#  'customer_support': {'description': 'Multi-channel customer support system',
#   'support_channels': ['Live Chat',
#    'Email',
#    'Phone',
# ...

# %%
gh = """ gh{scbbsc}"""

# %%
gh
# Out:
# ' gh{scbbsc}'

# %%
gh.format(scbbsc="alok")
# Out:
# ' ghalok'
